# %% [markdown]
# # Churn Prediction Modeling
# This notebook covers the machine learning aspect, utilizing Logistic Regression for interpretable churn drivers and predicting high-risk customers.

# %%
import pandas as pd
import sys
import os
sys.path.append('../src')
from data_preprocessing import get_preprocessed_pipeline
from churn_model import train_and_evaluate, extract_feature_importance

# Load cleaned data with business features
filepath = '../data/WA_Fn-UseC_-Telco-Customer-Churn.csv'
_, df_processed = get_preprocessed_pipeline(filepath)

# Train models and output evaluation metrics
lr_model, dt_model, feature_names = train_and_evaluate(df_processed)

# %% [markdown]
# ## Feature Importance
# What actually drives a customer to leave?

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(12,10))
img = mpimg.imread('../visuals/06_feature_importance.png')
plt.imshow(img)
plt.axis('off')
plt.show()
